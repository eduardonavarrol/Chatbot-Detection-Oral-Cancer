# %% [markdown]
# # Proyecto Cancer Bucal

# %% [markdown]
# ## Librerias

# %%
##Librerias
import cv2
import os
import shutil
import math
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.metrics import mean_squared_error

import warnings
warnings.filterwarnings("ignore")

import keras
from keras.layers import Dense,Conv2D, Flatten, MaxPool2D, Dropout
from keras.models import Sequential
from keras.preprocessing import image
from keras.callbacks import ModelCheckpoint
from keras.models import load_model

# %% [markdown]
# ## Contar Imagenes Procesadas

# %%
def GetDatasetSize(path):
    num_of_image = {}
    for folder in os.listdir(path):
        num_of_image[folder] = len(os.listdir(os.path.join(path, folder)));
    return num_of_image;

path = r'C:\Users\enavarro\Desktop\Eduardo\Proyecto_Bucal\DataSet\DataSet_Kaagle_2.0\Preprocesadas';
DatasetSize = GetDatasetSize(path);
print(DatasetSize);
# Out:
# {'cancer': 500, 'non-cancer': 450}

# %% [markdown]
# ## División de Datos

# %% [markdown]
# 70% Datos Entrenamiento
# 15% Datos Validación
# 15% Datos Testeo

# %%
def TrainValTestSplit(root_dir, classes_dir, val_ratio=0.15, test_ratio=0.15):
    for cls in classes_dir:
        train_path = os.path.join(r'C:\Users\enavarro\Desktop\Eduardo\Proyecto_Bucal\DataSet\DataSet_Kaagle_2.0\Division_Datos\Entrenamiento', cls)
        val_path = os.path.join(r'C:\Users\enavarro\Desktop\Eduardo\Proyecto_Bucal\DataSet\DataSet_Kaagle_2.0\Division_Datos\Validacion', cls)
        test_path = os.path.join(r'C:\Users\enavarro\Desktop\Eduardo\Proyecto_Bucal\DataSet\DataSet_Kaagle_2.0\Division_Datos\Testeo', cls)

        os.makedirs(train_path, exist_ok=True)
        os.makedirs(val_path, exist_ok=True)
        os.makedirs(test_path, exist_ok=True)

        src = os.path.join(root_dir, cls)

        allFileNames = os.listdir(src)
        np.random.shuffle(allFileNames)
        train_FileNames, val_FileNames, test_FileNames = np.split(np.array(allFileNames), [int(len(allFileNames) * (1 - (val_ratio + test_ratio))), int(len(allFileNames) * (1 - test_ratio))])

        train_FileNames = [os.path.join(src, name) for name in train_FileNames.tolist()]
        val_FileNames = [os.path.join(src, name) for name in val_FileNames.tolist()]
        test_FileNames = [os.path.join(src, name) for name in test_FileNames.tolist()]

        print(cls.upper(), ':')
        print('Total Imagenes: ', len(allFileNames))
        print('Entrenamiento: ', len(train_FileNames))
        print('Validación: ', len(val_FileNames))
        print('Testeo: ', len(test_FileNames))

        for name in train_FileNames:
            shutil.copy(name, train_path)

        for name in val_FileNames:
            shutil.copy(name, val_path)

        for name in test_FileNames:
            shutil.copy(name, test_path)
        print()

root_dir = r'C:\Users\enavarro\Desktop\Eduardo\Proyecto_Bucal\DataSet\DataSet_Kaagle_2.0\Procesadas'
classes_dir = ['cancer', 'non-cancer']  # Classes
TrainValTestSplit(root_dir, classes_dir)
# Out:
# CANCER :
# Total Imagenes:  464
# Entrenamiento:  324
# Validación:  70
# Testeo:  70
#
# NON-CANCER :
# Total Imagenes:  435
# Entrenamiento:  304
# Validación:  65
# Testeo:  66

# %% [markdown]
# # Construcción Modelos

# %% [markdown]
# ## DenseNet - 201

# %%
from tensorflow.keras.applications import DenseNet201
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import confusion_matrix
import tensorflow.keras.backend as K
import numpy as np

def specificity(y_true, y_pred):
    true_negatives = K.sum(K.round(K.clip((1 - y_true) * (1 - y_pred), 0, 1)))
    false_positives = K.sum(K.round(K.clip((1 - y_true) * y_pred, 0, 1)))
    return true_negatives / (true_negatives + false_positives + K.epsilon())

def sensitivity(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    false_negatives = K.sum(K.round(K.clip((1 - y_true) * y_pred, 0, 1)))
    return true_positives / (true_positives + false_negatives + K.epsilon())

modelo_DenseNet201 = DenseNet201(weights='imagenet', include_top=False, input_shape=(256, 256, 3))

for layer in modelo_DenseNet201.layers:
    layer.trainable = False

def crea_modelo_DenseNet201(base_model):
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = Dense(1024, activation='relu')(x)
    x = Dropout(0.5)(x)  
    predictions = Dense(1, activation='sigmoid')(x)

    modelo_combinado_DenseNet201 = Model(inputs=base_model.input, outputs=predictions)
    optimizer = Adam(learning_rate=0.0001)  # Ajusta la tasa de aprendizaje
    modelo_combinado_DenseNet201.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy', specificity, sensitivity])

    return modelo_combinado_DenseNet201

densenet_201 = crea_modelo_DenseNet201(modelo_DenseNet201)

from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(
    zoom_range=0.2,
    shear_range=0.2,
    rescale=1./255,
    horizontal_flip=True
)

val_datagen = ImageDataGenerator(rescale=1./255)

train_data = train_datagen.flow_from_directory(directory=r'C:\Users\enavarro\Desktop\Eduardo\Proyecto_Bucal\DataSet\DataSet_Kaagle_2.0\Division_Datos\Entrenamiento', target_size=(256,256), batch_size=32, class_mode='binary')
val_data = val_datagen.flow_from_directory(directory=r'C:\Users\enavarro\Desktop\Eduardo\Proyecto_Bucal\DataSet\DataSet_Kaagle_2.0\Division_Datos\Validacion', target_size=(256,256), batch_size=32, class_mode='binary')

checkpoint_callback = ModelCheckpoint(filepath="pt_control_modelo.keras", monitor='val_accuracy', verbose=1, save_best_only=True, mode='auto')
early_stopping_callback = EarlyStopping(monitor='val_loss', patience=10, verbose=1, restore_best_weights=True)

densenet201 = densenet_201.fit(
    train_data,
    steps_per_epoch=2,
    epochs=200,
    validation_data=val_data,
    validation_steps=1,
    callbacks=[checkpoint_callback, early_stopping_callback]
)

y_true = val_data.labels
y_pred = densenet_201.predict(val_data)
val_loss, val_accuracy, val_specificity, val_sensitivity = densenet_201.evaluate(val_data)
print(f"Loss: {val_loss}, Accuracy: {val_accuracy}, Specificity: {val_specificity}, Sensitivity: {val_sensitivity}")
# Out:
# Found 899 images belonging to 2 classes.
# Found 889 images belonging to 2 classes.
# Epoch 1/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.5703 - loss: 0.7442 - sensitivity: 0.4531 - specificity: 0.8516
# Epoch 1: val_accuracy improved from -inf to 0.62500, saving model to pt_control_modelo.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 45s 15s/step - accuracy: 0.5625 - loss: 0.7451 - sensitivity: 0.4583 - specificity: 0.8333 - val_accuracy: 0.6250 - val_loss: 0.6307 - val_sensitivity: 0.3438 - val_specificity: 0.4688
# Epoch 2/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.5078 - loss: 0.8085 - sensitivity: 0.5938 - specificity: 0.4297
# Epoch 2: val_accuracy did not improve from 0.62500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 6s/step - accuracy: 0.5104 - loss: 0.8008 - sensitivity: 0.5833 - specificity: 0.4271 - val_accuracy: 0.5938 - val_loss: 0.6503 - val_sensitivity: 0.5312 - val_specificity: 0.1250
# Epoch 3/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.5781 - loss: 0.7383 - sensitivity: 0.5156 - specificity: 0.2031
# Epoch 3: val_accuracy did not improve from 0.62500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 6s/step - accuracy: 0.5625 - loss: 0.7546 - sensitivity: 0.5000 - specificity: 0.2083 - val_accuracy: 0.5312 - val_loss: 0.7012 - val_sensitivity: 0.3750 - val_specificity: 0.1562
# Epoch 4/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.5312 - loss: 0.7006 - sensitivity: 0.4844 - specificity: 0.1875
# Epoch 4: val_accuracy improved from 0.62500 to 0.81250, saving model to pt_control_modelo.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 8s/step - accuracy: 0.5521 - loss: 0.6834 - sensitivity: 0.4896 - specificity: 0.2083 - val_accuracy: 0.8125 - val_loss: 0.5443 - val_sensitivity: 0.4688 - val_specificity: 0.4688
# Epoch 5/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.6484 - loss: 0.5815 - sensitivity: 0.5000 - specificity: 0.3828
# Epoch 5: val_accuracy did not improve from 0.81250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 9s 6s/step - accuracy: 0.6458 - loss: 0.5850 - sensitivity: 0.5000 - specificity: 0.3958 - val_accuracy: 0.7812 - val_loss: 0.5652 - val_sensitivity: 0.4375 - val_specificity: 0.5938
# Epoch 6/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7188 - loss: 0.5177 - sensitivity: 0.4922 - specificity: 0.6797
# Epoch 6: val_accuracy improved from 0.81250 to 0.87500, saving model to pt_control_modelo.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 12s 8s/step - accuracy: 0.6979 - loss: 0.5329 - sensitivity: 0.5000 - specificity: 0.6771 - val_accuracy: 0.8750 - val_loss: 0.4733 - val_sensitivity: 0.3750 - val_specificity: 0.6875
# Epoch 7/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.6797 - loss: 0.5832 - sensitivity: 0.5469 - specificity: 0.6484
# Epoch 7: val_accuracy did not improve from 0.87500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 6s/step - accuracy: 0.6875 - loss: 0.5724 - sensitivity: 0.5417 - specificity: 0.6458 - val_accuracy: 0.8438 - val_loss: 0.4503 - val_sensitivity: 0.5000 - val_specificity: 0.6562
# Epoch 8/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8125 - loss: 0.4466 - sensitivity: 0.4922 - specificity: 0.4922
# Epoch 8: val_accuracy did not improve from 0.87500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 7s/step - accuracy: 0.8125 - loss: 0.4485 - sensitivity: 0.4896 - specificity: 0.5104 - val_accuracy: 0.8438 - val_loss: 0.4128 - val_sensitivity: 0.5312 - val_specificity: 0.5625
# Epoch 9/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7500 - loss: 0.5660 - sensitivity: 0.5547 - specificity: 0.5391
# Epoch 9: val_accuracy did not improve from 0.87500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 9s 6s/step - accuracy: 0.7500 - loss: 0.5633 - sensitivity: 0.5521 - specificity: 0.5312 - val_accuracy: 0.8438 - val_loss: 0.5111 - val_sensitivity: 0.4375 - val_specificity: 0.5312
# Epoch 10/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8906 - loss: 0.3353 - sensitivity: 0.5312 - specificity: 0.4375
# Epoch 10: val_accuracy improved from 0.87500 to 0.90625, saving model to pt_control_modelo.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 8s/step - accuracy: 0.8854 - loss: 0.3501 - sensitivity: 0.5208 - specificity: 0.4479 - val_accuracy: 0.9062 - val_loss: 0.3372 - val_sensitivity: 0.5312 - val_specificity: 0.3750
# Epoch 11/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7969 - loss: 0.4207 - sensitivity: 0.5469 - specificity: 0.4219
# Epoch 11: val_accuracy did not improve from 0.90625
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 6s/step - accuracy: 0.7917 - loss: 0.4240 - sensitivity: 0.5417 - specificity: 0.4167 - val_accuracy: 0.8438 - val_loss: 0.4307 - val_sensitivity: 0.4688 - val_specificity: 0.4375
# Epoch 12/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - accuracy: 0.8205 - loss: 0.4022 - sensitivity: 0.4115 - specificity: 0.4948
# Epoch 12: val_accuracy did not improve from 0.90625
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 7s 4s/step - accuracy: 0.8232 - loss: 0.3983 - sensitivity: 0.4028 - specificity: 0.5139 - val_accuracy: 0.9062 - val_loss: 0.3772 - val_sensitivity: 0.4688 - val_specificity: 0.4375
# Epoch 13/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8594 - loss: 0.4085 - sensitivity: 0.4922 - specificity: 0.4922
# Epoch 13: val_accuracy did not improve from 0.90625
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 6s/step - accuracy: 0.8542 - loss: 0.4118 - sensitivity: 0.5000 - specificity: 0.4792 - val_accuracy: 0.7812 - val_loss: 0.4905 - val_sensitivity: 0.5000 - val_specificity: 0.4688
# Epoch 14/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8672 - loss: 0.3847 - sensitivity: 0.4375 - specificity: 0.5234
# Epoch 14: val_accuracy did not improve from 0.90625
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 6s/step - accuracy: 0.8646 - loss: 0.3893 - sensitivity: 0.4375 - specificity: 0.5312 - val_accuracy: 0.8438 - val_loss: 0.3890 - val_sensitivity: 0.4688 - val_specificity: 0.5625
# Epoch 15/200
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - accuracy: 0.7500 - loss: 0.4241 - sensitivity: 0.5000 - specificity: 0.4375
# Epoch 15: val_accuracy did not improve from 0.90625
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 7s 3s/step - accuracy: 0.7500 - loss: 0.4241 - sensitivity: 0.3750 - specificity: 0.3281 - val_accuracy: 0.7188 - val_loss: 0.4850 - val_sensitivity: 0.5625 - val_specificity: 0.6562
# Epoch 16/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8516 - loss: 0.3768 - sensitivity: 0.5312 - specificity: 0.4922
# Epoch 16: val_accuracy did not improve from 0.90625
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 13s 7s/step - accuracy: 0.8438 - loss: 0.3838 - sensitivity: 0.5417 - specificity: 0.4896 - val_accuracy: 0.8750 - val_loss: 0.2911 - val_sensitivity: 0.4062 - val_specificity: 0.5312
# Epoch 17/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8359 - loss: 0.4164 - sensitivity: 0.4375 - specificity: 0.5703
# Epoch 17: val_accuracy did not improve from 0.90625
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 6s/step - accuracy: 0.8333 - loss: 0.4150 - sensitivity: 0.4479 - specificity: 0.5729 - val_accuracy: 0.8750 - val_loss: 0.3187 - val_sensitivity: 0.3750 - val_specificity: 0.6875
# Epoch 18/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8750 - loss: 0.3096 - sensitivity: 0.5000 - specificity: 0.5625
# Epoch 18: val_accuracy did not improve from 0.90625
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 6s/step - accuracy: 0.8750 - loss: 0.3108 - sensitivity: 0.5104 - specificity: 0.5521 - val_accuracy: 0.8125 - val_loss: 0.3510 - val_sensitivity: 0.5938 - val_specificity: 0.4688
# Epoch 19/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8281 - loss: 0.3925 - sensitivity: 0.5156 - specificity: 0.4844
# Epoch 19: val_accuracy did not improve from 0.90625
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 6s/step - accuracy: 0.8229 - loss: 0.3949 - sensitivity: 0.5208 - specificity: 0.4688 - val_accuracy: 0.8750 - val_loss: 0.3250 - val_sensitivity: 0.5625 - val_specificity: 0.4375
# Epoch 20/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8203 - loss: 0.4233 - sensitivity: 0.5469 - specificity: 0.4297
# Epoch 20: val_accuracy improved from 0.90625 to 0.93750, saving model to pt_control_modelo.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 8s/step - accuracy: 0.8333 - loss: 0.4036 - sensitivity: 0.5312 - specificity: 0.4479 - val_accuracy: 0.9375 - val_loss: 0.2851 - val_sensitivity: 0.3438 - val_specificity: 0.6562
# Epoch 21/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8203 - loss: 0.4181 - sensitivity: 0.6641 - specificity: 0.4531
# Epoch 21: val_accuracy did not improve from 0.93750
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 6s/step - accuracy: 0.8229 - loss: 0.4180 - sensitivity: 0.6562 - specificity: 0.4583 - val_accuracy: 0.8125 - val_loss: 0.3483 - val_sensitivity: 0.5000 - val_specificity: 0.4375
# Epoch 22/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8594 - loss: 0.2887 - sensitivity: 0.5391 - specificity: 0.4609
# Epoch 22: val_accuracy did not improve from 0.93750
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 6s/step - accuracy: 0.8542 - loss: 0.2959 - sensitivity: 0.5417 - specificity: 0.4583 - val_accuracy: 0.7812 - val_loss: 0.4392 - val_sensitivity: 0.5000 - val_specificity: 0.3438
# Epoch 23/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8203 - loss: 0.3767 - sensitivity: 0.5391 - specificity: 0.4375
# Epoch 23: val_accuracy did not improve from 0.93750
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 7s/step - accuracy: 0.8125 - loss: 0.3813 - sensitivity: 0.5417 - specificity: 0.4375 - val_accuracy: 0.7500 - val_loss: 0.4990 - val_sensitivity: 0.2812 - val_specificity: 0.5938
# Epoch 24/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8828 - loss: 0.3320 - sensitivity: 0.4844 - specificity: 0.4297
# Epoch 24: val_accuracy did not improve from 0.93750
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 6s/step - accuracy: 0.8750 - loss: 0.3396 - sensitivity: 0.4896 - specificity: 0.4271 - val_accuracy: 0.9062 - val_loss: 0.3380 - val_sensitivity: 0.6250 - val_specificity: 0.4062
# Epoch 25/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7656 - loss: 0.3942 - sensitivity: 0.4219 - specificity: 0.4531
# Epoch 25: val_accuracy did not improve from 0.93750
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 7s/step - accuracy: 0.7812 - loss: 0.3819 - sensitivity: 0.4375 - specificity: 0.4479 - val_accuracy: 0.8438 - val_loss: 0.3275 - val_sensitivity: 0.5312 - val_specificity: 0.3750
# Epoch 26/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8125 - loss: 0.4043 - sensitivity: 0.5000 - specificity: 0.3438
# Epoch 26: val_accuracy did not improve from 0.93750
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 7s/step - accuracy: 0.7917 - loss: 0.4216 - sensitivity: 0.4896 - specificity: 0.3438 - val_accuracy: 0.9062 - val_loss: 0.2867 - val_sensitivity: 0.4688 - val_specificity: 0.5625
# Epoch 27/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9143 - loss: 0.2823 - sensitivity: 0.5859 - specificity: 0.4297
# Epoch 27: val_accuracy did not improve from 0.93750
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 7s 6s/step - accuracy: 0.8857 - loss: 0.2972 - sensitivity: 0.5590 - specificity: 0.4618 - val_accuracy: 0.8438 - val_loss: 0.3904 - val_sensitivity: 0.4688 - val_specificity: 0.6875
# Epoch 28/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7734 - loss: 0.3883 - sensitivity: 0.4531 - specificity: 0.5703
# Epoch 28: val_accuracy did not improve from 0.93750
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 9s 6s/step - accuracy: 0.7812 - loss: 0.3834 - sensitivity: 0.4688 - specificity: 0.5625 - val_accuracy: 0.8000 - val_loss: 0.3380 - val_sensitivity: 0.4800 - val_specificity: 0.7200
# Epoch 29/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8750 - loss: 0.3230 - sensitivity: 0.3984 - specificity: 0.6797
# Epoch 29: val_accuracy did not improve from 0.93750
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 7s 4s/step - accuracy: 0.8750 - loss: 0.3224 - sensitivity: 0.3958 - specificity: 0.6875 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_sensitivity: 0.0000e+00 - val_specificity: 0.0000e+00
# Epoch 30/200
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - accuracy: 0.8125 - loss: 0.3502 - sensitivity: 0.5000 - specificity: 0.6875
# Epoch 30: val_accuracy did not improve from 0.93750
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 7s 3s/step - accuracy: 0.8125 - loss: 0.3502 - sensitivity: 0.3750 - specificity: 0.5156 - val_accuracy: 0.8750 - val_loss: 0.3216 - val_sensitivity: 0.5312 - val_specificity: 0.5312
# Epoch 31/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8125 - loss: 0.4426 - sensitivity: 0.5234 - specificity: 0.5703
# Epoch 31: val_accuracy did not improve from 0.93750
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 12s 6s/step - accuracy: 0.8021 - loss: 0.4506 - sensitivity: 0.5417 - specificity: 0.5729 - val_accuracy: 0.9062 - val_loss: 0.2746 - val_sensitivity: 0.4062 - val_specificity: 0.6250
# Epoch 32/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8828 - loss: 0.3443 - sensitivity: 0.6719 - specificity: 0.4297
# Epoch 32: val_accuracy did not improve from 0.93750
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 6s/step - accuracy: 0.8854 - loss: 0.3419 - sensitivity: 0.6562 - specificity: 0.4375 - val_accuracy: 0.8750 - val_loss: 0.3407 - val_sensitivity: 0.5938 - val_specificity: 0.4688
# Epoch 33/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8359 - loss: 0.3845 - sensitivity: 0.3984 - specificity: 0.5312
# Epoch 33: val_accuracy did not improve from 0.93750
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 7s/step - accuracy: 0.8333 - loss: 0.3894 - sensitivity: 0.3958 - specificity: 0.5208 - val_accuracy: 0.9375 - val_loss: 0.2511 - val_sensitivity: 0.5000 - val_specificity: 0.4375
# Epoch 34/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8047 - loss: 0.4569 - sensitivity: 0.4531 - specificity: 0.4922
# Epoch 34: val_accuracy did not improve from 0.93750
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 6s/step - accuracy: 0.8229 - loss: 0.4284 - sensitivity: 0.4583 - specificity: 0.4896 - val_accuracy: 0.8750 - val_loss: 0.2435 - val_sensitivity: 0.4375 - val_specificity: 0.5625
# Epoch 35/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8359 - loss: 0.3661 - sensitivity: 0.4766 - specificity: 0.4219
# Epoch 35: val_accuracy did not improve from 0.93750
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 6s/step - accuracy: 0.8438 - loss: 0.3617 - sensitivity: 0.4896 - specificity: 0.4167 - val_accuracy: 0.9062 - val_loss: 0.2327 - val_sensitivity: 0.4062 - val_specificity: 0.5625
# Epoch 36/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9453 - loss: 0.2332 - sensitivity: 0.5000 - specificity: 0.5078
# Epoch 36: val_accuracy did not improve from 0.93750
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 7s/step - accuracy: 0.9375 - loss: 0.2337 - sensitivity: 0.4792 - specificity: 0.5208 - val_accuracy: 0.9062 - val_loss: 0.2675 - val_sensitivity: 0.5000 - val_specificity: 0.5312
# Epoch 37/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8438 - loss: 0.3318 - sensitivity: 0.5547 - specificity: 0.4453
# Epoch 37: val_accuracy did not improve from 0.93750
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 7s/step - accuracy: 0.8438 - loss: 0.3235 - sensitivity: 0.5521 - specificity: 0.4375 - val_accuracy: 0.9375 - val_loss: 0.2243 - val_sensitivity: 0.5312 - val_specificity: 0.4688
# Epoch 38/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8672 - loss: 0.2919 - sensitivity: 0.5781 - specificity: 0.4609
# Epoch 38: val_accuracy did not improve from 0.93750
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 7s/step - accuracy: 0.8646 - loss: 0.3029 - sensitivity: 0.5729 - specificity: 0.4583 - val_accuracy: 0.9062 - val_loss: 0.2383 - val_sensitivity: 0.3438 - val_specificity: 0.6875
# Epoch 39/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9062 - loss: 0.2837 - sensitivity: 0.3906 - specificity: 0.5938
# Epoch 39: val_accuracy did not improve from 0.93750
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 7s/step - accuracy: 0.9062 - loss: 0.2865 - sensitivity: 0.3958 - specificity: 0.5938 - val_accuracy: 0.8438 - val_loss: 0.2493 - val_sensitivity: 0.7188 - val_specificity: 0.3125
# Epoch 39: early stopping
# Restoring model weights from the end of the best epoch: 29.
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 105s 4s/step
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 90s 3s/step - accuracy: 0.8572 - loss: 0.3083 - sensitivity: 0.4684 - specificity: 0.6328
# Loss: 0.3436439037322998, Accuracy: 0.8436445593833923, Specificity: 0.6233035326004028, Sensitivity: 0.48303571343421936

# %%
print(f"Accuracy DenseNet201 = {val_accuracy * 100} %")
print(f"Perdida DenseNet201 = {val_loss * 100} %")
print(f"Especificidad DenseNet201 = {val_specificity * 100} %")
print(f"Sensibilidad DenseNet201 = {val_sensitivity * 100} %")
# Out:
# Accuracy DenseNet201 = 84.36445593833923 %
# Perdida DenseNet201 = 34.36439037322998 %
# Especificidad DenseNet201 = 62.33035326004028 %
# Sensibilidad DenseNet201 = 48.303571343421936 %

# %%
# Ajuste fino de algunas capas superiores del modelo
for layer in densenet_201.layers[-20:]:
    layer.trainable = True

# Compila nuevamente el modelo para el ajuste fino
densenet_201.compile(optimizer=Adam(learning_rate=0.0001), loss='binary_crossentropy', metrics=['accuracy', specificity, sensitivity])

# Entrena nuevamente el modelo con el ajuste fino
densenet201_fine_tuned = densenet_201.fit(
    train_data,
    steps_per_epoch=2,
    epochs=50,  # Número de épocas para el ajuste fino
    validation_data=val_data,
    validation_steps=1,
    callbacks=[checkpoint_callback, early_stopping_callback]
)
# Out:
# Epoch 1/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.7188 - loss: 0.6218 - sensitivity: 0.5703 - specificity: 0.6641
# Epoch 1: val_accuracy did not improve from 0.93750
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 47s 15s/step - accuracy: 0.7292 - loss: 0.6138 - sensitivity: 0.5833 - specificity: 0.6458 - val_accuracy: 0.8750 - val_loss: 0.3979 - val_sensitivity: 0.4062 - val_specificity: 0.4688
# Epoch 2/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9375 - loss: 0.3095 - sensitivity: 0.5703 - specificity: 0.4141
# Epoch 2: val_accuracy did not improve from 0.93750
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 7s/step - accuracy: 0.9271 - loss: 0.3244 - sensitivity: 0.5625 - specificity: 0.4062 - val_accuracy: 0.8125 - val_loss: 0.3421 - val_sensitivity: 0.5625 - val_specificity: 0.2500
# Epoch 3/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.6875 - loss: 0.5732 - sensitivity: 0.4062 - specificity: 0.2969
# Epoch 3: val_accuracy did not improve from 0.93750
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 7s/step - accuracy: 0.6875 - loss: 0.5742 - sensitivity: 0.4062 - specificity: 0.3021 - val_accuracy: 0.9062 - val_loss: 0.2632 - val_sensitivity: 0.5312 - val_specificity: 0.4375
# Epoch 4/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.7969 - loss: 0.3694 - sensitivity: 0.4453 - specificity: 0.3828
# Epoch 4: val_accuracy did not improve from 0.93750
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 7s/step - accuracy: 0.8021 - loss: 0.3649 - sensitivity: 0.4583 - specificity: 0.3854 - val_accuracy: 0.8125 - val_loss: 0.3912 - val_sensitivity: 0.5000 - val_specificity: 0.4375
# Epoch 5/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8594 - loss: 0.3147 - sensitivity: 0.5078 - specificity: 0.4141
# Epoch 5: val_accuracy did not improve from 0.93750
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 7s/step - accuracy: 0.8646 - loss: 0.3104 - sensitivity: 0.5000 - specificity: 0.4271 - val_accuracy: 0.9062 - val_loss: 0.3165 - val_sensitivity: 0.4688 - val_specificity: 0.5000
# Epoch 6/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9062 - loss: 0.2709 - sensitivity: 0.4609 - specificity: 0.6328
# Epoch 6: val_accuracy did not improve from 0.93750
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 7s/step - accuracy: 0.9062 - loss: 0.2743 - sensitivity: 0.4688 - specificity: 0.6250 - val_accuracy: 0.9375 - val_loss: 0.3356 - val_sensitivity: 0.5312 - val_specificity: 0.4688
# Epoch 7/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.8750 - loss: 0.3283 - sensitivity: 0.4609 - specificity: 0.6172
# Epoch 7: val_accuracy did not improve from 0.93750
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 7s/step - accuracy: 0.8750 - loss: 0.3329 - sensitivity: 0.4688 - specificity: 0.6146 - val_accuracy: 0.9375 - val_loss: 0.2145 - val_sensitivity: 0.5312 - val_specificity: 0.4688
# Epoch 8/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.7109 - loss: 0.5928 - sensitivity: 0.6328 - specificity: 0.6406
# Epoch 8: val_accuracy did not improve from 0.93750
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 7s/step - accuracy: 0.7292 - loss: 0.5650 - sensitivity: 0.6146 - specificity: 0.6354 - val_accuracy: 0.8125 - val_loss: 0.3821 - val_sensitivity: 0.2812 - val_specificity: 0.5938
# Epoch 9/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.8750 - loss: 0.3230 - sensitivity: 0.3281 - specificity: 0.6875
# Epoch 9: val_accuracy did not improve from 0.93750
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 7s/step - accuracy: 0.8854 - loss: 0.3127 - sensitivity: 0.3229 - specificity: 0.6875 - val_accuracy: 0.9375 - val_loss: 0.2180 - val_sensitivity: 0.6250 - val_specificity: 0.3750
# Epoch 10/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.8516 - loss: 0.3024 - sensitivity: 0.5234 - specificity: 0.5781
# Epoch 10: val_accuracy did not improve from 0.93750
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 7s/step - accuracy: 0.8542 - loss: 0.3077 - sensitivity: 0.5104 - specificity: 0.5729 - val_accuracy: 0.8125 - val_loss: 0.4237 - val_sensitivity: 0.4375 - val_specificity: 0.5625
# Epoch 10: early stopping
# Restoring model weights from the end of the best epoch: 1.

# %% [markdown]
# # TABLA RESUMEN

# %%
print(f"Accuracy DenseNet201 = {val_accuracy * 100} %")
print(f"Perdida DenseNet201 = {val_loss * 100} %")
print(f"Especificidad DenseNet201 = {val_specificity * 100} %")
print(f"Sensibilidad DenseNet201 = {val_sensitivity * 100} %")
# Out:
# Accuracy DenseNet201 = 84.36445593833923 %
# Perdida DenseNet201 = 34.36439037322998 %
# Especificidad DenseNet201 = 62.33035326004028 %
# Sensibilidad DenseNet201 = 48.303571343421936 %

# %% [markdown]
# # Graficos DenseNet 201

# %%
from scipy.signal import savgol_filter
import matplotlib.pyplot as plt

training_accuracy_densenet201 = densenet201.history['accuracy']
training_loss_densenet201 = densenet201.history['loss']
validation_accuracy_densenet201 = densenet201.history['val_accuracy']
validation_loss_densenet201 = densenet201.history['val_loss']

smoothed_training_accuracy201 = savgol_filter(training_accuracy_densenet201, window_length=10, polyorder=1)
smoothed_training_loss201 = savgol_filter(training_loss_densenet201, window_length=10, polyorder=1)
smoothed_validation_accuracy201 = savgol_filter(validation_accuracy_densenet201, window_length=10, polyorder=1)
smoothed_validation_loss201 = savgol_filter(validation_loss_densenet201, window_length=10, polyorder=1)

plt.plot(smoothed_training_accuracy201, label='Training precision')
plt.plot(smoothed_validation_accuracy201, label='Validation precisionn')
plt.title('DenseNet201 Precision Curve')
plt.xlabel('Epochs')
plt.ylabel('Value')
plt.legend()
plt.show()

plt.plot(smoothed_training_loss201, label='Training Loss')
plt.plot(smoothed_validation_loss201, label='Validation Loss')
plt.title('DenseNet201 Loss Curve')
plt.xlabel('Epochs')
plt.ylabel('Value')
plt.legend()
plt.show()

# %%
# Guardar Modelo Entrenado con mejor desempeño
densenet_201.save("Modelo_201.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
